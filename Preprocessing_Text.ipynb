# %%
import pandas as pd 
import numpy as np

TWEET_DATA = pd.read_csv("C:/Users/Irgi/Documents/Data/Raw Data/Clear/text_processing.csv", delimiter = ',')

TWEET_DATA.head()
# Out:
#                                                Tweet
# 0  Segera rilis tanggal  Mei di Korea dan udah te...
# 1  Enak banget cuma karna polos bisa debut main f...
# 2                                          Elon musk
# 3                                             Reyhan
# 4                                       jahat ya iya

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].str.lower()


print('Case Folding Result : \n')
print(TWEET_DATA['Tweet'].head(5))
# Out:
# Case Folding Result :
#
# 0    segera rilis tanggal  mei di korea dan udah te...
# 1    enak banget cuma karna polos bisa debut main f...
# 2                                            elon musk
# 3                                               reyhan
# 4                                         jahat ya iya
# Name: Tweet, dtype: object

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['Tweet'] = TWEET_DATA['Tweet'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['Tweet_tokens'] = TWEET_DATA['Tweet'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(TWEET_DATA['Tweet_tokens'].head())
# Out:
# Tokenizing Result :
#
# 0    [segera, rilis, tanggal, mei, di, korea, dan, ...
# 1    [enak, banget, cuma, karna, polos, bisa, debut...
# 2                                         [elon, musk]
# 3                                             [reyhan]
# 4                                     [jahat, ya, iya]
# Name: Tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['Tweet_tokens_fdist'] = TWEET_DATA['Tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(TWEET_DATA['Tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(rilis, 2), (di, 2), (segera, 1), (tanggal, 1...
# 1    [(enak, 1), (banget, 1), (cuma, 1), (karna, 1)...
# 2                               [(elon, 1), (musk, 1)]
# 3                                        [(reyhan, 1)]
# 4                      [(jahat, 1), (ya, 1), (iya, 1)]
# Name: Tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "di", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'nyg', 'hehe',
                       'pen', 'nan', 'loh', 'rt', '&amp', 'yah',
                       'di', 'bgt', 'gpp'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwords-id.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['Tweet_tokens_WSW'] = TWEET_DATA['Tweet_tokens'].apply(stopwords_removal) 

print('Stopwords Result : \n') 
print(TWEET_DATA['Tweet_tokens_WSW'].head())
# Out:
# Stopwords Result :
#
# 0    [rilis, tanggal, mei, korea, udah, terjual, ne...
# 1    [enak, banget, karna, polos, debut, main, film...
# 2                                         [elon, musk]
# 3                                             [reyhan]
# 4                                         [jahat, iya]
# Name: Tweet_tokens_WSW, dtype: object

# %%
normalizad_word = pd.read_excel("C:/Users/Irgi/Documents/.ipynb_checkpoints/normalisasi.xlsx", engine="openpyxl")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['Tweet_normalized'] = TWEET_DATA['Tweet_tokens_WSW'].apply(normalized_term)

print('Normalize Result : \n') 
TWEET_DATA['Tweet_normalized'].head(10)
# Out:
# Normalize Result :
# 0    [rilis, tanggal, mei, korea, sudah, terjual, n...
# 1    [enak, banget, karna, polos, debut, main, film...
# 2                                         [elon, musk]
# 3                                             [reyhan]
# 4                                         [jahat, iya]
# 5                                        [bokep, indo]
# 6                                               [beli]
# 7                [animator, film, the, hobbit, hunger]
# 8                     [written, in, bahasa, indonesia]
# 9                          [purely, review, rate, aku]
# Name: Tweet_normalized, dtype: object

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['Tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['Tweet_tokens_stemmed'] = TWEET_DATA['Tweet_normalized'].swifter.apply(get_stemmed_term)
print(TWEET_DATA['Tweet_tokens_stemmed'])
# Out:
# 1008
# ------------------------
# rilis : rilis
# tanggal : tanggal
# mei : mei
# korea : korea
# sudah : sudah
# terjual : jual
# negara : negara
# indonesia : indonesia
# bioskop : bioskop
# indo : indo
# nonton : nonton
# enak : enak
# banget : banget
# karna : karna
# polos : polos
# debut : debut
# main : main
# filmapakabar : filmapakabar
# kariernya : karier
# bangun : bangun
# nol : nol
# tenggelam : tenggelam
# palung : palung
# mariana : mariana
# elon : elon
# musk : musk
# reyhan : reyhan
# jahat : jahat
# iya : iya
# bokep : bokep
# beli : beli
# animator : animator
# film : film
# the : the
# hobbit : hobbit
# hunger : hunger
# written : written
# in : in
# bahasa : bahasa
# purely : purely
# review : review
# rate : rate
# aku : aku
# met : met
# founder : founder
# interviewed : interviewed
# kandidat : kandidat
# kejora : kejora
# seorang : orang
# chief : chief
# investment : investment
# officer : officer
# perusahaan : usaha
# triliunan : triliun
# calon : calon
# biz : biz
# counterpart : counterpart
# dr : dr
# meta : meta
# thai : thai
# investors : investors
# producer : producer
# owner : owner
# shu : shu
# guo : guo
# yin : yin
# xiang : xiang
# kenyangggg : kenyangggg
# emm : emm
# bocil : bocil
# kematian : mati
# project : project
# bareng : bareng
# artis : artis
# papan : papan
# komika : komika
# selebgram : selebgram
# patut : patut
# tunggu : tunggu
# nanya : nanya
# horor : horor
# serem : rem
# rekomendasiin : rekomendasiin
# istilah : istilah
# planet : planet
# anak : anak
# sd : sd
# ditipu : tipu
# negeri : negeri
# bhs : bhs
# kamu : kamu
# nunjukin : nunjukin
# baca : baca
# buku : buku
# pelajaran : ajar
# sejarah : sejarah
# dunia : dunia
# terfavorit : favorit
# versi : versi
# sinemaksimal : maksimal
# judul : judul
# aslinya : asli
# soorarai : soorarai
# pottru : pottru
# hindi : hindi
# udaan : uda
# melewati : lewat
# link : link
# semawur : semawur
# group : group
# highlight : highlight
# tema : tema
# religi : religi
# nasionalisreligius : nasionalisreligius
# laporan : lapor
# minggu : minggu
# selengkapnya : lengkap
# cerita : cerita
# muda : muda
# heboh : heboh
# halo : halo
# fh : fh
# ui : ui
# diragukan : ragu
# sbg : sbg
# terlahir : lahir
# perempuan : perempuan
# tinggal : tinggal
# vulgar : vulgar
# dlm : dlm
# artian : arti
# terangan : terang
# kasih : kasih
# liat : liat
# pov : pov
# hidup : hidup
# dikasih : kasih
# pilihan : pilih
# nurut : nurut
# bae : bae
# same : same
# vibes : vibes
# kayak : kayak
# suster : suster
# keramas : keramas
# viral : viral
# an : an
# pemainnya : main
# jav : jav
# boyz : boyz
# th : th
# kit : kit
# ready : ready
# kmember : kmember
# wajib : wajib
# pair : pair
# lholder : lholder
# frame : frame
# keyring : keyring
# book : book
# package : package
# binder : binder
# index : index
# incl : incl
# packing : packing
# bekasi : bekas
# ina : ina
# layar : layar
# lebar : lebar
# restorasi : restorasi
# ngabuburit : ngabuburit
# imam : imam
# ahmad : ahmad
# bin : bin
# hanbal : hanbal
# pasarnya : pasar
# suka : suka
# marvel : marvel
# dilanjut : lanjut
# mengisi : isi
# kegiatan : giat
# ramadan : ramadan
# mimin : mimin
# list : list
# ditonton : tonton
# geser : geser
# sampai : sampai
# slide : slide
# selasa : selasa
# april : april
# wib : wib
# rangkaianalur : rangkaianalur
# faktanya : fakta
# sinetron : sinetron
# india : india
# dendam : dendam
# berbuah : buah
# intrik : intrik
# mudah : mudah
# terbaca : baca
# arahnya : arah
# muspeners : muspeners
# movie : movie
# mvs : mvs
# ngetweet : ngetweet
# dukung : dukung
# stop : stop
# cintai : cinta
# produk : produk
# senin : senin
# membahas : bahas
# selesai : selesai
# ujian : uji
# cm : cm
# second : second
# rabu : rabu
# quiz : quiz
# show : show
# kamis : kamis
# rekomendasi : rekomendasi
# lagumusik : lagumusik
# indie : indie
# jumat : jumat
# kpop : kpop
# sabtu : sabtu
# akdong : akdong
# seoul : seoul
# my : my
# name : name
# is : is
# khan : khan
# srk : srk
# perjuangan : juang
# muslim : muslim
# menghadapi : hadap
# diskriminasi : diskriminasi
# as : as
# follow : follow
# tebak : tebak
# tonton : tonton
# netlix : netlix
# spam : spam
# ok : ok
# bukti : bukti
# kekejian : keji
# kadrun : kadrun
# sembelih : sembelih
# anggota : anggota
# densus : densus
# tayang : tayang
# agustus : agustus
# biopik : biopik
# grup : grup
# lawak : lawak
# legendaris : legendaris
# srimulat : srimulat
# hil : hil
# mustahal : mustahal
# babak : babak
# cinpolis : cinpolis
# cinemas : cemas
# temukankebahagiaanmu : temukankebahagiaanmu
# novia : novia
# terharu : haru
# bangga : bangga
# menjelang : jelang
# magrib : magrib
# pertamanya : pertama
# denger : denger
# md : md
# jg : jg
# uda : uda
# serius : serius
# keren : keren
# baguslah : bagus
# kelas : kelas
# kualitasnya : kualitas
# yuk : yuk
# bangsa : bangsa
# bodoh : bodoh
# ribut : ribut
# penistaan : nista
# agama : agama
# one : one
# day : day
# separoh : separoh
# manusia : manusia
# mampus : mampus
# spt : spt
# avenger : avenger
# end : end
# game : game
# bennyrhamdani : bennyrhamdani
# hanura : hanura
# from : from
# zero : zero
# to : to
# hero : hero
# filmkuntilanak : filmkuntilanak
# hbo : hbo
# go : go
# max : max
# private : private
# seriesfilm : seriesfilm
# originals : originals
# lengkap : lengkap
# akses : akses
# vpn : vpn
# usa : usa
# gada : gada
# sub : sub
# pakai : pakai
# available : available
# asia : asia
# genre : genre
# dramedy : dramedy
# why : why
# bagus : bagus
# bentuknya : bentuk
# animasi : animasi
# premis : premis
# bangunan : bangun
# konflik : konflik
# resolusinya : resolusi
# orang : orang
# chinese : chinese
# musik : musik
# menikmati : nikmat
# kalangan : kalang
# melayu : melayu
# makannya : makan
# baguss : baguss
# salut : salut
# alur : alur
# ceritanya : cerita
# cgv : cgv
# semuaserudicgv : semuaserudicgv
# mawar : mawar
# eva : eva
# de : de
# jongh : jongh
# lahir : lahir
# september : september
# aktris : aktris
# penyanyi : nyanyi
# model : model
# berkebangsaan : bangsa
# keturunan : turun
# belandakaro : belandakaro
# pengakuan : aku
# perannya : peran
# annelies : annelies
# mellema : mellema
# bumi : bumi
# diajak : ajak
# temen : temen
# pas : pas
# ulangg : ulangg
# searching : searching
# dimana : mana
# donggg : donggg
# fix : fix
# sihhh : sihhh
# filmnya : film
# mouly : mouly
# surya : surya
# underrated : underrated
# gambaran : gambar
# kecreepyannya : kecreepyannya
# lirik : lirik
# marlina : marlina
# pembunuh : bunuh
# first : first
# third : third
# love : love
# imperfect : imperfect
# photocopier : photocopier
# mariposa : mariposa
# ali : ali
# ratu : ratu
# queens : queens
# perfect : perfect
# fit : fit
# makmum : makmum
# bebas : bebas
# mantan : mantan
# manten : manten
# jajan : jajan
# transaksi : transaksi
# pembayaran : bayar
# qris : qris
# ewallet : ewallet
# pilihanmu : pilih
# lho : lho
# syuting : syuting
# taman : taman
# victoria : victoria
# dipenuhi : penuh
# fans : fans
# pahlawan : pahlawan
# devisa : devisa
# hong : hong
# kong : kong
# tri : tri
# suaka : suaka
# ama : ama
# zidan : zidan
# sepatutnya : patut
# mengolok : olok
# babang : babang
# tamvan : tamvan
# andhika : andhika
# twivortiare : twivortiare
# raihaanun : raihaanun
# yawlaaaaa : yawlaaaaa
# keberhasilan : hasil
# mencatat : catat
# juta : juta
# penonton : tonton
# menempatkan : tempat
# pandemi : pandemi
# covid : covid
# ribu : ribu
# fantasi : fantasi
# berangkat : berangkat
# momen : momen
# tokoh : tokoh
# dinda : dinda
# belajar : ajar
# mengontrol : kontrol
# power : power
# dapatnya : dapat
# sekolah : sekolah
# mata : mata
# hati : hati
# sinema : sinema
# butuh : butuh
# mengangkat : angkat
# isuisu : isuisu
# berlatar : latar
# ragam : ragam
# budaya : budaya
# nusantara : nusantara
# jawa : jawa
# mbak : mbak
# tidak : tidak
# langganan : langgan
# netflix : netflix
# tontonan : tonton
# seru : seru
# disana : sana
# kejar : kejar
# bridgerton : bridgerton
# deynias : deynias
# senandung : senandung
# awan : awan
# terlibat : libat
# penggarapan : garap
# gamau : gamau
# internet : internet
# pdfnya : pdfnya
# cari : cari
# dibaca : baca
# sinepil : pil
# coba : coba
# ah : ah
# menit : menit
# miris : miris
# kesel : kesel
# takjub : takjub
# dah : dah
# ginian : ginian
# jaman : jaman
# digeruduk : digeruduk
# massa : massa
# help : help
# spread : spread
# nobar : nobar
# khusus : khusus
# grand : grand
# jakarta : jakarta
# penjualan : jual
# tiket : tiket
# titian : titi
# serambut : rambut
# dibelah : belah
# tujuh : tujuh
# mari : mari
# ramaikan : ramai
# htm : htm
# rp : rp
# reservasi : reservasi
# mengambil : ambil
# videoku : video
# pidato : pidato
# debutku : debut
# lupa : lupa
# aplikasi : aplikasi
# vidio : vidio
# saksikan : saksi
# diaku : dia
# imamku : imam
# spesial : spesial
# genflix : genflix
# simak : simak
# artikel : artikel
# web : web
# karakter : karakter
# sutradara : sutradara
# sempatkan : sempat
# krisis : krisis
# kepercayaan : percaya
# dijamin : jamin
# oke : oke
# langsung : langsung
# deh : deh
# salah : salah
# terbaik : baik
# download : download
# tag : tag
# gen : gen
# al : al
# waqiah : waqiah
# gofar : gofar
# bank : bank
# karina : karina
# pagi : pagi
# snowdrop : snowdrop
# winter : winter
# kuntilanak : kuntilanak
# garagara : garagara
# warisan : waris
# kkn : kkn
# desa : desa
# penari : tari
# jack : jack
# sparrow : sparrow
# thread : thread
# tujuan : tuju
# tingkat : tingkat
# presentasi : presentasi
# kemampuan : mampu
# sedia : sedia
# daerah : daerah
# nasional : nasional
# internasional : internasional
# takarir : takarir
# sedunia : dunia
# perempuanperdamaian : perempuanperdamaian
# jaseng : jaseng
# serang : serang
# recommended : recommended
# score : score
# prangko : prangko
# peringatan : ingat
# hubungan : hubung
# bilateral : bilateral
# dokumenter : dokumenter
# menipu : tipu
# kawin : kawin
# cerai : cerai
# korupsi : korupsi
# narkoba : narkoba
# masuk : masuk
# penjarashow : penjarashow
# televisi : televisi
# podcast : podcast
# media : media
# terkenal : kenal
# kemkominfo : kemkominfo
# platejohnny : platejohnny
# nggak : nggak
# deng : deng
# becanda : becanda
# jagahutan : jagahutan
# jagamasadepan : jagamasadepan
# donasikomik : donasikomik
# military : military
# prosecutor : prosecutor
# doberman : doberman
# eps : eps
# moon : moon
# knight : knight
# devils : devils
# sister : sister
# rindu : rindu
# dibayar : bayar
# tuntas : tuntas
# puluhan : puluh
# tinggali : tinggal
# biarkan : biar
# perawatan : awat
# proses : proses
# alam : alam
# alih : alih
# horror : horror
# sebutkan : sebut
# nama : nama
# pasangan : pasang
# suami : suami
# istri : istri
# aktor : aktor
# relate : relate
# kehidupan : hidup
# remaja : remaja
# skrg : skrg
# gitu : gitu
# identik : identik
# warna : warna
# ungu : ungu
# nantikan : nanti
# keseruan : seru
# aksi : aksi
# cc : cc
# adiwriter : adiwriter
# arahan : arah
# park : park
# chanwook : chanwook
# old : old
# boy : boy
# handmaiden : handmaiden
# terbaru : baru
# sosok : sosok
# wanitawanita : wanitawanita
# hebat : hebat
# losmenbubroto : losmenbubroto
# setuju : tuju
# manis : manis
# khas : khas
# maksa : maksa
# sayangnya : sayang
# hilang : hilang
# romansa : romansa
# kesukaan : suka
# oma : oma
# demonic : demonic
# jokowi : jokowi
# dibintangi : bintang
# tipikal : tipikal
# cocok : cocok
# disaksikan : saksi
# keluarga : keluarga
# aman : aman
# anakanak : anakanak
# giliran : gilir
# islam : islam
# makan : makan
# kurma : kurma
# teriak : teriak
# arabisasi : arab
# congratulation : congratulation
# emmanuelle : emmanuelle
# memantapkan : mantap
# penggunaan : guna
# aspek : aspek
# shebuildspeaceindonesia : shebuildspeaceindonesia
# here : here
# we : we
# again : again
# dikutip : kutip
# susi : sus
# susanti : susanti
# all : all
# abis : abis
# maju : maju
# djs : djs
# browsing : browsing
# kartini : kartini
# pake : pake
# indihome : indihome
# festival : festival
# toronto : toronto
# international : international
# ffi : ffi
# launching : launching
# bestie : bestie
# yuni : yuni
# nominasi : nominasi
# membawa : bawa
# pulang : pulang
# piala : piala
# pemeran : per
# utama : utama
# arawinda : arawinda
# kirana : kirana
# disney : disney
# hotstar : hotstar
# penghargaan : harga
# kisah : kisah
# impian : impi
# wanita : wanita
# vs : vs
# realitas : realitas
# lingkungan : lingkung
# mendukung : dukung
# dikisahkan : kisah
# terbelenggu : belenggu
# pilihannya : pilih
# melanjutkan : lanjut
# pendidikan : didik
# topik : topik
# feminisme : feminisme
# berhasil : hasil
# memenangkan : menang
# inspiratif : inspiratif
# mewakili : wakil
# kondisi : kondisi
# bangett : bangett
# berkualitas : kualitas
# banyaknya : banyak
# mimpi : mimpi
# dipaksa : paksa
# menyerah : serah
# berkembang : kembang
# ngasih : ngasih
# patriarki : patriark
# kental : kental
# pokoknya : pokok
# dapet : dapet
# kepooo : kepooo
# gaaa : gaaa
# sii : sii
# yukkk : yukkk
# lochh : lochh
# oh : oh
# kemaren : kemaren
# trending : trending
# meraih : raih
# acara : acara
# melek : melek
# berhak : hak
# memilih : pilih
# jalan : jalan
# hidupnya : hidup
# sadar : sadar
# terikat : ikat
# nikah : nikah
# sulit : sulit
# menentukan : tentu
# menarik : tarik
# sesuai : sesuai
# satunya : satu
# penasaran : penasaran
# tuhh : tuhh
# bercerita : cerita
# dngan : dngan
# kisahnya : kisah
# related : related
# cewek : cewek
# menyenangkan : senang
# yok : yok
# lihat : lihat
# disneyhostar : disneyhostar
# hostar : hostar
# pembebasan : bebas
# perjalanan : jalan
# permasalahan : masalah
# struktural : struktural
# masyarakat : masyarakat
# emilianus : emilianus
# uk : uk
# patar : patar
# well : well
# jajang : jajang
# noer : noer
# benerbener : benerbener
# beneran : beneran
# mengcarry : mengcarry
# sinematografinya : sinematografi
# penulisannya : tulis
# ngangkat : ngangkat
# isu : isu
# kritik : kritik
# sosial : sosial
# gk : gk
# tanggungtanggung : tanggungtanggung
# konservatif : konservatif
# utamanya : utama
# paul : paul
# dano : dano
# telat : telat
# puasa : puasa
# sekuel : sekuel
# outlaws : outlaws
# amerika : amerika
# perancis : perancis
# jerman : jerman
# singapura : singapura
# dll : dll
# roundup : roundup
# comeback : comeback
# ma : ma
# dongseok : dongseok
# eternals : eternals
# dir : dir
# hanung : hanung
# bramantyo : bramantyo
# iman : iman
# brotoseno : brotoseno
# sim : sim
# berhenti : henti
# bermimpi : mimpi
# berkarya : karya
# hayoo : hayoo
# favoritmu : favorit
# reply : reply
# gratis : gratis
# pembelian : beli
# cinepolis : cepol
# berlaku : laku
# niki : nik
# menulis : tulis
# memproduseri : produser
# lagunya : lagu
# ost : ost
# ngefans : ngefans
# harikartini : harikartini
# disegaja : disegaja
# perdana : perdana
# dita : dita
# karang : karang
# losmen : losmen
# bu : bu
# broto : broto
# riri : riri
# pohan : pohan
# asisten : asisten
# semangat : semangat
# membara : bara
# terang : terang
# kegelapan : gelap
# segarkan : segar
# spirit : spirit
# pelopor : pelopor
# kebangkitan : bangkit
# filmfilm : filmfilm
# hebart : hebart
# bernuansa : nuansa
# emansipasi : emansipasi
# persamaan : sama
# hak : hak
# kukira : kira
# kau : kau
# rumah : rumah
# diputar : putar
# dear : dear
# nathan : nathan
# thank : thank
# you : you
# salma : salma
# tutuge : tutuge
# sang : sang
# saudagar : saudagar
# tabepuang : tabepuang
# hora : hora
# horaa : horaa
# habis : habis
# gelap : gelap
# terbitlah : terbit
# nenek : nenek
# giselle : giselle
# suho : suho
# jepang : jepang
# dreamersdaily : dreamersdaily
# harga : harga
# sharing : sharing
# platinum : platinum
# kbulan : kbulan
# kelebihan : lebih
# iklan : iklan
# konten : konten
# serial : serial
# video : video
# series : series
# drama : drama
# tayangan : tayang
# olahraga : olahraga
# ligue : ligue
# ucl : ucl
# serie : serie
# nba : nba
# ktahun : ktahun
# drakor : drakor
# vlu : vlu
# hd : hd
# quallity : quallity
# offline : offline
# login : login
# hplaptopsmart : hplaptopsmart
# tv : tv
# pertamatama : pertamatama
# senang : senang
# mendengar : dengar
# highlow : highlow
# dubbing : dubbing
# hotsar : hotsar
# liverpool : liverpool
# yuta : yuta
# berperan : peran
# shigeyuki : shigeyuki
# susaki : susaki
# vid : vid
# cr : cr
# nctyutalove : nctyutalove
# sangeaaaaaaaaaah : sangeaaaaaaaaaah
# aespacoachella : aespacoachella
# txt : txt
# konsep : konsep
# tuyul : tuyul
# mnet : mnet
# shopeegratisongkirrp : shopeegratisongkirrp
# nct : nct
# dirilis : rilis
# high : high
# low : low
# worst : worst
# cross : cross
# joel : joel
# fadly : fadly
# cast : cast
# nadila : nadila
# syahra : syahra
# larez : larez
# asril : asril
# sani : sani
# ikram : ikram
# reza : reza
# pahlevi : pahlevi
# fitry : fitry
# laluna : laluna
# semoga : moga
# lakilaki : lakilaki
# terkuat : kuat
# senomon : senomon
# bernama : nama
# ryo : ryo
# eng : eng
# trans : trans
# poteato : poteato
# smnct : smnct
# full : full
# teasernya : teasernya
# selamat : selamat
# dibutuhin : dibutuhin
# translate : translate
# ya : ya
# china : china
# mengeksplorasi : eksplorasi
# epen : epen
# tim : tim
# muspen : muspen
# menyelenggarakan : selenggara
# temanteman : temanteman
# panti : panti
# asuhan : asuh
# yayasan : yayasan
# dompet : dompet
# dhuafa : dhuafa
# heran : heran
# bisabisanya : bisabisanya
# paham : paham
# sihirsihiran : sihirsihiran
# ortu : ortu
# novel : novel
# hp : hp
# inanewstv : inanewstv
# lingsirwingi : lingsirwingi
# cadangan : cadang
# vip : vip
# panggil : panggil
# ci : ci
# anime : anime
# menyukai : suka
# sekalinya : sekali
# ikutan : ikut
# sayembara : sayembara
# pantun : pantun
# diumumkan : umum
# umumkan : umum
# pemenangnya : menang
# judulnya : judul
# anjing : anjing
# diem : diem
# kek : kek
# ngepost : ngepost
# kena : kena
# siapaa : siapaa
# donny : donny
# yen : yen
# industri : industri
# kreatif : kreatif
# memiliki : milik
# karakteristik : karakteristik
# tersendiri : sendiri
# unik : unik
# batin : batin
# johan : johan
# vries : vries
# tentara : tentara
# menyangka : sangka
# penugasannnya : penugasannnya
# hindia : hindia
# penuh : penuh
# darah : darah
# air : air
# seakan : akan
# divonis : vonis
# laku : laku
# {'rilis': 'rilis', 'tanggal': 'tanggal', 'mei': 'mei', 'korea': 'korea', 'sudah': 'sudah', 'terjual': 'jual', 'negara': 'negara', 'indonesia': 'indonesia', 'bioskop': 'bioskop', 'indo': 'indo', 'nonton': 'nonton', 'enak': 'enak', 'banget': 'banget', 'karna': 'karna', 'polos': 'polos', 'debut': 'debut', 'main': 'main', 'filmapakabar': 'filmapakabar', 'kariernya': 'karier', 'bangun': 'bangun', 'nol': 'nol', 'tenggelam': 'tenggelam', 'palung': 'palung', 'mariana': 'mariana', 'elon': 'elon', 'musk': 'musk', 'reyhan': 'reyhan', 'jahat': 'jahat', 'iya': 'iya', 'bokep': 'bokep', 'beli': 'beli', 'animator': 'animator', 'film': 'film', 'the': 'the', 'hobbit': 'hobbit', 'hunger': 'hunger', 'written': 'written', 'in': 'in', 'bahasa': 'bahasa', 'purely': 'purely', 'review': 'review', 'rate': 'rate', 'aku': 'aku', 'met': 'met', 'founder': 'founder', 'interviewed': 'interviewed', 'kandidat': 'kandidat', 'kejora': 'kejora', 'seorang': 'orang', 'chief': 'chief', 'investment': 'investment', 'officer': 'officer', 'perusahaan': 'usaha', 'triliunan': 'triliun', 'calon': 'calon', 'biz': 'biz', 'counterpart': 'counterpart', 'dr': 'dr', 'meta': 'meta', 'thai': 'thai', 'investors': 'investors', 'producer': 'producer', 'owner': 'owner', 'shu': 'shu', 'guo': 'guo', 'yin': 'yin', 'xiang': 'xiang', 'kenyangggg': 'kenyangggg', 'emm': 'emm', 'bocil': 'bocil', 'kematian': 'mati', 'project': 'project', 'bareng': 'bareng', 'artis': 'artis', 'papan': 'papan', 'komika': 'komika', 'selebgram': 'selebgram', 'patut': 'patut', 'tunggu': 'tunggu', 'nanya': 'nanya', 'horor': 'horor', 'serem': 'rem', 'rekomendasiin': 'rekomendasiin', 'istilah': 'istilah', 'planet': 'planet', 'anak': 'anak', 'sd': 'sd', 'ditipu': 'tipu', 'negeri': 'negeri', 'bhs': 'bhs', 'kamu': 'kamu', 'nunjukin': 'nunjukin', 'baca': 'baca', 'buku': 'buku', 'pelajaran': 'ajar', 'sejarah': 'sejarah', 'dunia': 'dunia', 'terfavorit': 'favorit', 'versi': 'versi', 'sinemaksimal': 'maksimal', 'judul': 'judul', 'aslinya': 'asli', 'soorarai': 'soorarai', 'pottru': 'pottru', 'hindi': 'hindi', 'udaan': 'uda', 'melewati': 'lewat', 'link': 'link', 'semawur': 'semawur', 'group': 'group', 'highlight': 'highlight', 'tema': 'tema', 'religi': 'religi', 'nasionalisreligius': 'nasionalisreligius', 'laporan': 'lapor', 'minggu': 'minggu', 'selengkapnya': 'lengkap', 'cerita': 'cerita', 'muda': 'muda', 'heboh': 'heboh', 'halo': 'halo', 'fh': 'fh', 'ui': 'ui', 'diragukan': 'ragu', 'sbg': 'sbg', 'terlahir': 'lahir', 'perempuan': 'perempuan', 'tinggal': 'tinggal', 'vulgar': 'vulgar', 'dlm': 'dlm', 'artian': 'arti', 'terangan': 'terang', 'kasih': 'kasih', 'liat': 'liat', 'pov': 'pov', 'hidup': 'hidup', 'dikasih': 'kasih', 'pilihan': 'pilih', 'nurut': 'nurut', 'bae': 'bae', 'same': 'same', 'vibes': 'vibes', 'kayak': 'kayak', 'suster': 'suster', 'keramas': 'keramas', 'viral': 'viral', 'an': 'an', 'pemainnya': 'main', 'jav': 'jav', 'boyz': 'boyz', 'th': 'th', 'kit': 'kit', 'ready': 'ready', 'kmember': 'kmember', 'wajib': 'wajib', 'pair': 'pair', 'lholder': 'lholder', 'frame': 'frame', 'keyring': 'keyring', 'book': 'book', 'package': 'package', 'binder': 'binder', 'index': 'index', 'incl': 'incl', 'packing': 'packing', 'bekasi': 'bekas', 'ina': 'ina', 'layar': 'layar', 'lebar': 'lebar', 'restorasi': 'restorasi', 'ngabuburit': 'ngabuburit', 'imam': 'imam', 'ahmad': 'ahmad', 'bin': 'bin', 'hanbal': 'hanbal', 'pasarnya': 'pasar', 'suka': 'suka', 'marvel': 'marvel', 'dilanjut': 'lanjut', 'mengisi': 'isi', 'kegiatan': 'giat', 'ramadan': 'ramadan', 'mimin': 'mimin', 'list': 'list', 'ditonton': 'tonton', 'geser': 'geser', 'sampai': 'sampai', 'slide': 'slide', 'selasa': 'selasa', 'april': 'april', 'wib': 'wib', 'rangkaianalur': 'rangkaianalur', 'faktanya': 'fakta', 'sinetron': 'sinetron', 'india': 'india', 'dendam': 'dendam', 'berbuah': 'buah', 'intrik': 'intrik', 'mudah': 'mudah', 'terbaca': 'baca', 'arahnya': 'arah', 'muspeners': 'muspeners', 'movie': 'movie', 'mvs': 'mvs', 'ngetweet': 'ngetweet', 'dukung': 'dukung', 'stop': 'stop', 'cin ...
# ------------------------
# Pandas Apply:   0%|          | 0/356 [00:00<?, ?it/s]
# 0      [rilis, tanggal, mei, korea, sudah, jual, nega...
# 1      [enak, banget, karna, polos, debut, main, film...
# 2                                           [elon, musk]
# 3                                               [reyhan]
# 4                                           [jahat, iya]
#                              ...
# 351                             [film, baru, donny, yen]
# 352    [industri, film, salah, industri, kreatif, mil...
# 353    [konflik, batin, johan, de, vries, tentara, mu...
# 354                                  [akan, vonis, laku]
# 355    [tonton, film, favorit, april, beli, tiket, gr...
# Name: Tweet_tokens_stemmed, Length: 356, dtype: object

# %%
TWEET_DATA.head()
# Out:
#                                                Tweet  \
# 0  segera rilis tanggal mei di korea dan udah ter...
# 1  enak banget cuma karna polos bisa debut main f...
# 2                                          elon musk
# 3                                             reyhan
# 4                                       jahat ya iya
#
#                                         Tweet_tokens  \
# 0  [segera, rilis, tanggal, mei, di, korea, dan, ...
# 1  [enak, banget, cuma, karna, polos, bisa, debut...
# 2                                       [elon, musk]
# 3                                           [reyhan]
# 4                                   [jahat, ya, iya]
#
#                                   Tweet_tokens_fdist  \
# 0  {'segera': 1, 'rilis': 2, 'tanggal': 1, 'mei':...
# 1  {'enak': 1, 'banget': 1, 'cuma': 1, 'karna': 1...
# 2                             {'elon': 1, 'musk': 1}
# 3                                      {'reyhan': 1}
# 4                    {'jahat': 1, 'ya': 1, 'iya': 1}
#
#                                     Tweet_tokens_WSW  \
# 0  [rilis, tanggal, mei, korea, udah, terjual, ne...
# 1  [enak, banget, karna, polos, debut, main, film...
# 2                                       [elon, musk]
# 3                                           [reyhan]
# 4                                       [jahat, iya]
#
#                                     Tweet_normalized  \
# 0  [rilis, tanggal, mei, korea, sudah, terjual, n...
# 1  [enak, banget, karna, polos, debut, main, film...
# 2                                       [elon, musk]
# 3                                           [reyhan]
# 4                                       [jahat, iya]
#
#                                 Tweet_tokens_stemmed
# 0  [rilis, tanggal, mei, korea, sudah, jual, nega...
# 1  [enak, banget, karna, polos, debut, main, film...
# 2                                       [elon, musk]
# 3                                           [reyhan]
# 4                                       [jahat, iya]

# %%
TWEET_DATA = TWEET_DATA [['Tweet']]

# %%
TWEET_DATA.sort_values("Tweet", inplace = True)
TWEET_DATA.drop_duplicates(subset ="Tweet", keep = False, inplace = True)

# %%
TWEET_DATA.to_csv("Text_Preprocessing.csv")
